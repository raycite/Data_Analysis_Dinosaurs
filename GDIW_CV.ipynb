# %% [markdown]
# <a href="https://colab.research.google.com/github/raycite/Data_Analysis_Dinosaurs/blob/main/GDIW_CV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GDIW 2025 Workshop
# ## Bridging AI and Impact: Computer Vision in Key Sectors
# ### 🎯 Objective 1: Understand Fundamentals of Computer Vision and AI
#
# Welcome to the first part of our workshop on **“Bridging AI and Impact: Computer Vision in Key Sectors”**.
#
# In this section, we’ll explore what **Artificial Intelligence (AI)**, **Machine Learning (ML)**, and **Computer Vision (CV)** mean — and how they connect to the real world.
#
# ---
#
# ### 🔍 What You’ll Learn
# - What is AI and how it works
# - The relationship between AI, ML, and Deep Learning
# - How computers “see” using Computer Vision
# - Introduction to Neural Networks and CNNs
#
# ---
#
# ### 🤖 Key Concepts Simplified
#
# | Concept | Description |
# |----------|--------------|
# | **Artificial Intelligence (AI)** | The science of making computers perform tasks that usually require human intelligence. |
# | **Machine Learning (ML)** | A subset of AI where systems learn from data instead of explicit programming. |
# | **Deep Learning (DL)** | Uses multi-layered neural networks to recognize complex patterns in data (especially images). |
# | **Computer Vision (CV)** | Enables computers to interpret and understand visual data like images and videos. |
# | **Neural Networks** | Algorithms inspired by how the human brain processes information. |
# | **Convolutional Neural Networks (CNNs)** | A special type of neural network used in image recognition and object detection. |
#
# ---
#
# ### 🧩 Understanding How CV Works
#
# When humans see an image, our brains identify shapes, edges, and patterns.
# Computer Vision tries to replicate that process using mathematical models.
#
# Example process:

# %%
# 🧠 Demonstration: How Computers See Images

# Importing libraries
import cv2
import matplotlib.pyplot as plt

# Load an example image (you can upload your own image in Colab)
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4fd574fb-6d60-47d4-9e72-566f8eb63019" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4fd574fb-6d60-47d4-9e72-566f8eb63019">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# Get the uploaded filename
import io
import os
image_name = list(uploaded.keys())[0]

# Read and convert the image to RGB
img = cv2.imread(image_name)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(6,6))
plt.imshow(img_rgb)
plt.title("👁️ Computer Vision in Action – Image Loaded")
plt.axis('off')
plt.show()
# Out:
# /usr/local/lib/python3.12/dist-packages/IPython/core/pylabtools.py:151: UserWarning: Glyph 128065 (\N{EYE}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
# 🧠 Demonstration: How Computers See Images (Improved Version)

# Import necessary libraries
import cv2
import matplotlib.pyplot as plt
from google.colab import files

# Upload an image file
print("📤 Upload an image file to visualize:")
uploaded = files.upload()

# Get the uploaded filename
image_name = list(uploaded.keys())[0]

# Read the image using OpenCV (BGR by default)
img = cv2.imread(image_name)

# Convert to RGB color format for correct display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image properly with a clean layout
plt.figure(figsize=(6, 6))
plt.imshow(img_rgb)
plt.title("Computer Vision in Action – Image Loaded", fontsize=14)
plt.axis('off')  # Hides the axes for a clean look
plt.show()
# Out:
# 📤 Upload an image file to visualize:
#      <input type="file" id="files-fa789d81-17f9-47f1-8d30-aaffb1f10e45" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fa789d81-17f9-47f1-8d30-aaffb1f10e45">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %% [markdown]
# ### 💬 Discussion Prompts
#
# - What does it mean for a computer to "see"?
# - Can computers really understand images, or just detect patterns?
# - How could image recognition help in **agriculture** or **healthcare** in Ghana?
#
# ---
#
# ✅ **Summary**
#
# You’ve just learned the fundamentals of AI and how computer vision allows systems to interpret visual information.
# In the next section, we’ll move into **real-world applications** of these technologies across Agriculture, Healthcare, and Security.

# %%
# ======================================
# 🧠 Objective 1: Understand Fundamentals of Computer Vision and AI
# ======================================

from IPython.display import Markdown, display
import cv2
import matplotlib.pyplot as plt
import numpy as np

# --- Text introduction (shows nicely in Colab) ---
display(Markdown("""
# 🧩 Objective 1: Understanding the Fundamentals of Computer Vision and AI

### 👁️ What is Computer Vision?
Computer Vision (CV) is a field of Artificial Intelligence that enables computers to **see, interpret, and understand visual information** — much like humans do.

In this section, we’ll explore how a computer “sees” an image using Python.
"""))

# --- Step 1: Upload and display an image ---
display(Markdown("### 🖼️ Step 1: Upload and View an Image"))

# 👉 Upload your image (for example, a photo or object)
from google.colab import files
uploaded = files.upload()

# Get uploaded file name
image_path = list(uploaded.keys())[0]

# Read and convert to RGB (OpenCV loads as BGR by default)
img = cv2.imread(image_path)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the image
plt.figure(figsize=(6, 4))
plt.imshow(img_rgb)
plt.axis('off')
plt.title("👁️ How the Computer Sees Your Image")
plt.show()

# --- Step 2: Explore image as numerical data ---
display(Markdown("""
### 🔢 Step 2: Understanding the Image as Data
To a computer, an image is not just a photo — it’s a **matrix (array) of numbers**.

Each pixel has **three values**: Red, Green, and Blue (RGB).
Let's take a look at the image’s structure.
"""))

# Display shape (height, width, color channels)
display(Markdown(f"**Image shape:** `{img_rgb.shape}` (Height, Width, Color Channels)"))

# Show pixel values from a small region
x, y = 50, 50  # pick a pixel
pixel_value = img_rgb[y, x]
display(Markdown(f"**Sample pixel value at (x={x}, y={y}):** `{pixel_value}`"))

# Show top-left corner zoom (50x50 region)
zoom = img_rgb[:50, :50]
plt.figure(figsize=(3, 3))
plt.imshow(zoom)
plt.axis('off')
plt.title("🔍 Zoomed-in Section (Top-Left 50x50 pixels)")
plt.show()

display(Markdown("""
> 🧠 **Takeaway:**
> - Computers interpret images as **arrays of pixel intensities**, not as visual scenes.
> - Each pixel’s RGB values help the computer learn features such as edges, colors, and patterns — the building blocks of computer vision models.
"""))
# Out:
# # 🧩 Objective 1: Understanding the Fundamentals of Computer Vision and AI
#
# ### 👁️ What is Computer Vision?
# Computer Vision (CV) is a field of Artificial Intelligence that enables computers to **see, interpret, and understand visual information** — much like humans do.
#
# In this section, we’ll explore how a computer “sees” an image using Python.
# ### 🖼️ Step 1: Upload and View an Image
#      <input type="file" id="files-ff45d8f7-7445-455f-bd30-a5388d2d061c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ff45d8f7-7445-455f-bd30-a5388d2d061c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# ...

# %%
# ======================================
# ⚪ Step 2: Convert to Grayscale
# ======================================

import numpy as np

display(Markdown("""
### Step 2: Convert the Image to Grayscale
Each pixel in a grayscale image contains **one intensity value** instead of three (R, G, B).
This makes it easier for algorithms to detect **edges and shapes**.
"""))

# Convert to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

plt.figure(figsize=(6,4))
plt.imshow(gray, cmap='gray')
plt.axis("off")
plt.title("Grayscale Image")
plt.show()

display(Markdown(f"**Image shape (grayscale):** `{gray.shape}`"))
# Out:
# ### Step 2: Convert the Image to Grayscale
# Each pixel in a grayscale image contains **one intensity value** instead of three (R, G, B).
# This makes it easier for algorithms to detect **edges and shapes**.
# **Image shape (grayscale):** `(183, 275)`

# %%
# ======================================
# 🔎 Compare Zoomed-Out vs Zoomed-In (Standalone)
# ======================================

from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import cv2

display(Markdown("""
### Comparing Zoom Out vs Zoom In
When **zoomed out**, your eye blends pixels into smooth shapes.
When **zoomed in**, you see how every pixel intensity contributes to the image.
"""))

# Reload grayscale image
gray = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2GRAY)
h, w = gray.shape
zoom_region = gray[h//3:h//3+50, w//3:w//3+50]

fig, ax = plt.subplots(1, 2, figsize=(10,4))

# Zoomed-out (whole image)
ax[0].imshow(gray, cmap='gray')
ax[0].set_title("Zoom Out – Smooth Image View")
ax[0].axis("off")

# Zoomed-in (small region)
ax[1].imshow(zoom_region, cmap='gray', interpolation='nearest')
ax[1].set_title("Zoom In – Visible Pixels")
ax[1].axis("off")

plt.show()

display(Markdown("""
> 🧠 **Observation:**
> - Each square is a **pixel** (0 = black, 255 = white).
> - The computer always sees **numbers**, even when we see shapes.
> - Zooming out averages neighboring pixels into smooth forms.
"""))
# Out:
# ### Comparing Zoom Out vs Zoom In
# When **zoomed out**, your eye blends pixels into smooth shapes.
# When **zoomed in**, you see how every pixel intensity contributes to the image.
# > 🧠 **Observation:**
# > - Each square is a **pixel** (0 = black, 255 = white).
# > - The computer always sees **numbers**, even when we see shapes.
# > - Zooming out averages neighboring pixels into smooth forms.

# %%
# ======================================
# 🔎 Compare Zoomed-Out vs Zoomed-In with Region Highlight
# ======================================

from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import cv2

display(Markdown("""
### Comparing Zoom Out vs Zoom In
When **zoomed out**, the image appears smooth and continuous.
When **zoomed in**, individual **pixels** (tiny squares of intensity) become visible.
"""))

# Reload grayscale image
gray = cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2GRAY)

# Define zoom region coordinates
h, w = gray.shape
x, y, size = w//3, h//3, 60
zoom_region = gray[y:y+size, x:x+size]

# Draw rectangle on full image to show zoom region
image_with_box = gray.copy()
cv2.rectangle(image_with_box, (x, y), (x+size, y+size), (255, 0, 0), 2)

# Plot side-by-side
fig, ax = plt.subplots(1, 2, figsize=(12,5))

# Zoomed-out (full image with red box)
ax[0].imshow(image_with_box, cmap='gray')
ax[0].set_title("Zoom Out – Full Image (Region Highlighted)")
ax[0].axis("off")

# Zoomed-in (just that region, magnified)
ax[1].imshow(zoom_region, cmap='gray', interpolation='nearest')
ax[1].set_title("Zoom In – Pixel Level View")
ax[1].axis("off")

plt.show()

display(Markdown("""
> 🧠 **Observation:**
> - The left image shows the full picture — how humans perceive patterns.
> - The right image shows the raw data — how computers perceive pixels.
> - Computer vision models are trained to recognize meaning from these pixel patterns.
"""))
# Out:
# ### Comparing Zoom Out vs Zoom In
# When **zoomed out**, the image appears smooth and continuous.
# When **zoomed in**, individual **pixels** (tiny squares of intensity) become visible.
# > 🧠 **Observation:**
# > - The left image shows the full picture — how humans perceive patterns.
# > - The right image shows the raw data — how computers perceive pixels.
# > - Computer vision models are trained to recognize meaning from these pixel patterns.
